# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
sns.boxplot(x='sepal_width',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
import sklearn
from sklearn.datasets import load_boston

# %%
q1=np.percentile(df['sepal_width'],25,interpolation='midpoint')
q3=np.percentile(df['sepal_width'],75,interpolation='midpoint')
iqr=q3-q1
upper=np.where(df['sepal_width']>(q3+1.5*iqr))
lower=np.where(df['sepal_width']<(q1-1.5*iqr))
print(upper)
print("------------------------------------------------------------------------------")
print(lower)

df.drop(upper[0],inplace=True)
df.drop(lower[0],inplace=True)
df.shape

print(df)
# Out:
# (array([15, 32, 33], dtype=int64),)
# ------------------------------------------------------------------------------
# (array([60], dtype=int64),)
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# ...

# %%
sns.boxplot(x='sepal_width',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
dff=pd.read_csv('f:\\housing-price prediction.csv')

# %%
dff
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3      NaN      2.0      yes
# 1             2   38500.0     4000         2      1.0      1.0      yes
# 2             3   49500.0     3060         3      1.0      1.0      yes
# 3             4   60500.0     6650         3      NaN      NaN      yes
# 4             5   61000.0     6360         2      1.0      1.0      NaN
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0     4800         3      2.0      4.0      yes
# 542         543   94000.0     6000         3      2.0      4.0      yes
# 543         544  103000.0     6000         3      2.0      4.0      yes
# 544         545  105000.0     6000         3      2.0      2.0      yes
# 545         546  105000.0     6000         3      1.0      2.0      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# ...

# %%
dff.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3      NaN      2.0      yes      no
# 1           2  38500.0     4000         2      1.0      1.0      yes      no
# 2           3  49500.0     3060         3      1.0      1.0      yes     NaN
# 3           4  60500.0     6650         3      NaN      NaN      yes     yes
# 4           5  61000.0     6360         2      1.0      1.0      NaN      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
dff.tail()
dff.describe()
# Out:
#        Unnamed: 0          price       lotsize    bedrooms     bathrms  \
# count  546.000000     546.000000    546.000000  546.000000  544.000000
# mean   273.500000   68121.597070   5150.265568    2.965201    1.286765
# std    157.760895   26702.670926   2168.158725    0.737388    0.502782
# min      1.000000   25000.000000   1650.000000    1.000000    1.000000
# 25%    137.250000   49125.000000   3600.000000    2.000000    1.000000
# 50%    273.500000   62000.000000   4600.000000    3.000000    1.000000
# 75%    409.750000   82000.000000   6360.000000    3.000000    2.000000
# max    546.000000  190000.000000  16200.000000    6.000000    4.000000
#
#           stories    garagepl
# count  544.000000  546.000000
# mean     1.808824    0.692308
# std      0.869069    0.861307
# min      1.000000    0.000000
# 25%      1.000000    0.000000
# 50%      2.000000    0.000000
# 75%      2.000000    1.000000
# max      4.000000    3.000000

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  546 non-null    int64
#  1   price       546 non-null    float64
#  2   lotsize     546 non-null    int64
#  3   bedrooms    546 non-null    int64
#  4   bathrms     544 non-null    float64
#  5   stories     544 non-null    float64
#  6   driveway    544 non-null    object
#  7   recroom     543 non-null    object
#  8   fullbase    546 non-null    object
#  9   gashw       546 non-null    object
#  10  airco       546 non-null    object
#  11  garagepl    546 non-null    int64
#  12  prefarea    546 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 55.6+ KB

# %%
dff.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       0
# bedrooms      0
# bathrms       2
# stories       2
# driveway      2
# recroom       3
# fullbase      0
# gashw         0
# airco         0
# garagepl      0
# prefarea      0
# dtype: int64

# %%
dff['bathrms'].fillna('not ',inplace=True)
dff['stories'].fillna('not ',inplace=True)
dff['driveway'].fillna('not ',inplace=True)

# %%
dff.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       0
# bedrooms      0
# bathrms       0
# stories       0
# driveway      0
# recroom       3
# fullbase      0
# gashw         0
# airco         0
# garagepl      0
# prefarea      0
# dtype: int64

# %%
i=dff['recroom'].mode().values[0]
dff['recroom']=dff['recroom'].replace(np.nan,i)

# %%
dff.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# lotsize       0
# bedrooms      0
# bathrms       0
# stories       0
# driveway      0
# recroom       0
# fullbase      0
# gashw         0
# airco         0
# garagepl      0
# prefarea      0
# dtype: int64

# %%
sns.boxplot(x='price',data=dff)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
q1=np.percentile(dff['price'],25,interpolation='midpoint')
q3=np.percentile(dff['price'],75,interpolation='midpoint')
iqr=q3-q1
upper=np.where(dff['price']>=(q3+1.5*iqr))
lower=np.where(dff['price']<=(q1-1.5*iqr))
print(upper)
print("------------------------------------------------------------------------------")
print(lower)

dff.drop(upper[0],inplace=True)
dff.drop(lower[0],inplace=True)
dff.shape

print(dff)
# Out:
# (array([ 92, 103, 216, 331, 337, 338, 361, 362, 368, 375, 376, 377, 382,
#        418, 436], dtype=int64),)
# ------------------------------------------------------------------------------
# (array([], dtype=int64),)
#      Unnamed: 0     price  lotsize  bedrooms bathrms stories driveway recroom  \
# 0             1   42000.0     5850         3    not      2.0      yes      no
# 1             2   38500.0     4000         2     1.0     1.0      yes      no
# 2             3   49500.0     3060         3     1.0     1.0      yes      no
# 3             4   60500.0     6650         3    not     not       yes     yes
# 4             5   61000.0     6360         2     1.0     1.0     not       no
# ..          ...       ...      ...       ...     ...     ...      ...     ...
# 541         542   91500.0     4800         3     2.0     4.0      yes     yes
# 542         543   94000.0     6000         3     2.0     4.0      yes      no
# ...

# %%
sns.boxplot(x='price',data=dff)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
dff['price'].mean()
# Out:
# 65754.41054613936

# %%
df1=pd.read_csv('f:\\height_weight_eda.csv')

# %%
print(df1)
print(df1.shape)
# Out:
#     Height  Weight
# 0     1.47     NaN
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4      NaN   57.20
# 5     1.60   58.57
# 6     1.63     NaN
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70     NaN
# 10    1.73   66.28
# 11     NaN   68.10
# 12     NaN   69.92
# 13    1.80   72.19
# 14    1.83   74.46
# (15, 2)

# %%
df1.describe()
# Out:
#           Height     Weight
# count  12.000000  12.000000
# mean    1.638333  62.880000
# std     0.115902   7.248456
# min     1.470000  53.120000
# 25%     1.542500  56.860000
# 50%     1.640000  62.200000
# 75%     1.707500  68.555000
# max     1.830000  74.460000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  12 non-null     float64
#  1   Weight  12 non-null     float64
# dtypes: float64(2)
# memory usage: 368.0 bytes

# %%
df1.isnull().sum()
# Out:
# Height    3
# Weight    3
# dtype: int64

# %%
df1.head()
# Out:
#    Height  Weight
# 0    1.47     NaN
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4     NaN   57.20

# %%
df1.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11     NaN   68.10
# 12     NaN   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df1['Height'].fillna(df1['Height'].mean(),inplace=True)
df1['Weight'].fillna(df1['Weight'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df1
# Out:
#       Height  Weight
# 0   1.470000   62.88
# 1   1.500000   53.12
# 2   1.520000   54.48
# 3   1.550000   55.84
# 4   1.638333   57.20
# 5   1.600000   58.57
# 6   1.630000   62.88
# 7   1.650000   61.29
# 8   1.680000   63.11
# 9   1.700000   62.88
# 10  1.730000   66.28
# 11  1.638333   68.10
# 12  1.638333   69.92
# 13  1.800000   72.19
# 14  1.830000   74.46

# %%
sns.boxplot(x='Height',data=df1)
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
df2=pd.read_csv('f:\\salary-yearsofexperience.csv')

# %%
df2
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5       NaN
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               NaN   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7       NaN
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              NaN   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3       NaN
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              NaN   91738.0
# 21              7.1       NaN
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
# ...

# %%
print(df2)
print(df2.shape)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5       NaN
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               NaN   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7       NaN
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              NaN   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3       NaN
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              NaN   91738.0
# 21              7.1       NaN
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  32 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %%
df2.describe()
# Out:
#        YearsExperience         Salary
# count        32.000000      30.000000
# mean          6.468750   84482.333333
# std           3.714178   32281.632984
# min           1.100000   39343.000000
# 25%           3.575000   56988.000000
# 50%           5.600000   74650.500000
# 75%           9.525000  113517.750000
# max          13.500000  139465.000000

# %%
df2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5      NaN
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df2.tail()
# Out:
#     YearsExperience    Salary
# 30             11.2       NaN
# 31             11.5  126756.0
# 32             12.3  128765.0
# 33             12.9  135675.0
# 34             13.5  139465.0

# %%
df2.isnull().sum()
# Out:
# YearsExperience    3
# Salary             5
# dtype: int64

# %%
df2['YearsExperience'].fillna(df2['YearsExperience'].mean(),inplace=True)
df2['Salary'].fillna(df2['Salary'].mean(),inplace=True)

# %%
df2
# Out:
#     YearsExperience         Salary
# 0           1.10000   39343.000000
# 1           1.30000   46205.000000
# 2           1.50000   84482.333333
# 3           2.00000   43525.000000
# 4           2.20000   39891.000000
# 5           6.46875   56642.000000
# 6           3.00000   60150.000000
# 7           3.20000   54445.000000
# 8           3.20000   64445.000000
# 9           3.70000   84482.333333
# 10          3.90000   63218.000000
# 11          4.00000   55794.000000
# 12          4.00000   56957.000000
# 13          6.46875   57081.000000
# 14          4.50000   61111.000000
# 15          4.90000   67938.000000
# 16          5.10000   66029.000000
# 17          5.30000   84482.333333
# 18          5.90000   81363.000000
# 19          6.00000   93940.000000
# 20          6.46875   91738.000000
# 21          7.10000   84482.333333
# 22          7.90000  101302.000000
# 23          8.20000  113812.000000
# 24          8.70000  109431.000000
# 25          9.00000  105582.000000
# ...

# %%
sns.boxplot(x='Salary',data=df2)
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
df3=pd.read_csv('f:\\loan prediction dataset in banking.csv')

# %%
df3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df3.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df3.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df3.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df3.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df3['Gender'].fillna('not',inplace=True)
df3['Married'].fillna('not',inplace=True)
df3['Dependents'].fillna('not',inplace=True)
df3['Self_Employed'].fillna('not',inplace=True)

# %%
df3.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df3['Loan_Amount_Term'].fillna(df3['Loan_Amount_Term'].mean(),inplace=True)

# %%
i=df3['Credit_History'].mode().values[0]
df3['Credit_History']=df3['Credit_History'].replace(np.nan,i)

# %%
df3.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df3['LoanAmount'].fillna(df3['LoanAmount'].mean(),inplace=True)

# %%
df3.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sns.boxplot(x='LoanAmount',data=df3)
# Out:
# <AxesSubplot:xlabel='LoanAmount'>

# %%
q1=np.percentile(df3['LoanAmount'],25,interpolation='midpoint')
q3=np.percentile(df3['LoanAmount'],75,interpolation='midpoint')
iqr=q3-q1
upper=np.where(df3['LoanAmount']>=(q3+1.5*iqr))
lower=np.where(df3['LoanAmount']<=(q1-1.5*iqr))
print(upper)
print("------------------------------------------------------------------------------")
print(lower)

df3.drop(upper[0],inplace=True)
df3.drop(lower[0],inplace=True)
df3.shape

print(df3)
# Out:
# (array([  5,   9,  21,  34,  54,  67,  83, 126, 130, 135, 155, 161, 171,
#        177, 233, 253, 258, 260, 278, 308, 324, 325, 333, 351, 369, 372,
#        381, 391, 409, 432, 487, 506, 514, 523, 525, 536, 561, 572, 592,
#        600, 604], dtype=int64),)
# ------------------------------------------------------------------------------
# (array([], dtype=int64),)
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# ...

# %%
sns.boxplot(x='LoanAmount',data=df3)
# Out:
# <AxesSubplot:xlabel='LoanAmount'>
