# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
dftip=sns.load_dataset('tips')

# %%
#sea born gives easy ways to create the plot.
#better way of visualization
#in sea born there are different dataset hence it loads the dataset online reporistory...tips,tatainic,breastcancer and many more

# %%
dftip#is a dataframe which has all this columns
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to check the realationship (scatter plot),positive corelation
sns.relplot(x='total_bill',y='tip',data=dftip)
plt.show()
#total_bill is independent(predictor)variable where as tip is dependent

# %%
#sex,smoke,day,time.size-categorical
#totalbill,tip-continuse
sns.relplot(x='total_bill',y='tip',hue='sex',data=dftip)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',hue='day',data=dftip)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',style='day',data=dftip)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',style='day',size='size',data=dftip)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',style='smoker',col='day',col_wrap=2,data=dftip)
plt.show()

# %%
dftip.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(dftip.corr())
plt.show()

# %%
sns.pairplot(dftip)
plt.show()

# %%
dftitanic=sns.load_dataset('titanic')

# %%
dftitanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
dftitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(dftitanic)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\New folder\Python\envs\envr1\lib\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 sns.pairplot(dftitanic)
#       2 plt.show()
#
# File D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
# ...

# %%
dftitanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
iris=sns.load_dataset('iris')

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=dftip)
plt.show()

# %%
sns.distplot(dftip.total_bill)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(dftip.total_bill,kde=False,bins=15)
plt.show()

# %%
sns.distplot(dftip.total_bill,hist=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dftip.total_bill,rug=True)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x='day',y='total_bill',data=dftip)
plt.show()

# %%
dftip.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot('sex',data=dftip)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x='sex',y='total_bill',data=dftip)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=dftip)
plt.show()

# %% [markdown]
# what is data sci?
# data,dataset,trained dataset,test dataset,validate data set
# Observations=row
# features=columns
# Dependent variable-and all others are dependent
# Independent variable-there will be one independent variable
# Labeled data

# %% [markdown]
# EDA-Exploratory Data Analysis

# %%
bar plot-discrete data
histogram-continuous data

# %%
dfiris=sns.load_dataset('iris')

# %%
dfiris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dfiris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#corelated with each other
plt.scatter(x='sepal_length',y='sepal_width',data=dfiris)
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_width',hue='species',data=dfiris)
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_width',hue='species',size='sepal_width',data=dfiris)
plt.show()

# %%
sns.relplot(x='sepal_length',y='sepal_width',hue='species',col='species',col_wrap=2,data=dfiris)
plt.show()

# %%
dfiris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(dfiris.corr())
plt.show()

# %%
sns.pairplot(dfiris)
plt.show()

# %%
dfdi=sns.load_dataset('diamonds')

# %%
dfdi
#tell me dependent and independent 
#corelation
#plot the graphs
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.heatmap(dfdi.corr())
plt.show()

# %%
sns.relplot(x='carat',y='price',hue='cut',data=dfdi)
plt.show()

# %%
sns.relplot(x='carat',y='price',hue='cut',style='color',data=dfdi)
plt.show()

# %%
sns.relplot(x='carat',y='price',hue='cut',col='clarity',size='depth',col_wrap=2,data=dfdi)
plt.show()

# %%
sns.pairplot(dfdi)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.relplot(x='x',y='y',hue='cut',style='color',data=dfdi)
plt.show()

# %%
sns.relplot(x='depth',y='table',hue='color',style='clarity',data=dfdi)
plt.show()

# %%
sns.jointplot(x='carat',y='price',data=dfdi)
plt.show()

# %%
sns.distplot(dfdi.carat)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dfdi.carat,rug=True)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dfdi.carat,hist=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
dffli=sns.load_dataset('flights')

# %%
dffli
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
dffli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
sns.relplot(x='year',y='passengers',data=dffli)
plt.show()

# %%
sns.relplot(x='year',y='passengers',hue='month',style='month',data=dffli)
plt.show()

# %%
sns.relplot(x='year',y='passengers',hue='month',col='month',col_wrap=4,data=dffli)
plt.show()

# %%
sns.heatmap(dffli.corr())
plt.show()

# %%
sns.pairplot(dffli)
plt.show()

# %%
sns.jointplot(x='year',y='passengers',data=dffli)
plt.show()

# %%
dftaxis=sns.load_dataset('taxis')

# %%
dftaxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
dftaxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
dftaxis.corr()
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
sns.heatmap(dftaxis.corr())
plt.show()

# %%
sns.relplot(x='distance',y='fare',hue='payment',data=dftaxis)
plt.show()

# %%
sns.relplot(x='distance',y='fare',hue='color',style='payment',data=dftaxis)
plt.show()

# %%
sns.relplot(x='distance',y='fare',hue='color',style='payment',col='color',col_wrap=3,data=dftaxis)
plt.show()

# %%
sns.pairplot(dftaxis)
plt.show()

# %%
sns.jointplot(x='distance',y='total',data=dftaxis)
plt.show()

# %%
sns.jointplot(x='distance',y='fare',data=dftaxis,kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=dftip,kind='hex')
plt.show()

# %%
sns.distplot(dftip.total_bill,kde=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dftip.total_bill,hist=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x='sex',y='total_bill',data=dftip)
plt.show()
dftip.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.boxplot(x='day',y='total_bill',data=dftip)
plt.show()

# %%
#univarient ananlysis-is done using boxplot
sns.boxplot(x='sex',y='total_bill',data=dftip)
plt.show()

# %%
sns.rugplot(dftip.total_bill)
plt.show()

# %%
sns.distplot(dffli.passengers,kde=False)
plt.show()#kde used for checking for kernaldensity estimation

# %%
sns.distplot(dffli.passengers)
plt.show()

# %%
sns.distplot(dffli.passengers,hist=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x='year',y='passengers',data=dffli)
plt.show()
dffli.year.value_counts()
# Out:
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: year, dtype: int64

# %%
sns.boxplot(x='year',y='passengers',data=dffli)
plt.show()

# %%
sns.rugplot(dffli.passengers)
plt.show()

# %%
dfcar=sns.load_dataset('car_crashes')

# %%
dfcar
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
dfcar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
sns.heatmap(dfcar.corr())
plt.show()

# %%
sns.relplot(x='total',y='ins_premium',hue='no_previous',data=dfcar)
plt.show()

# %%
sns.relplot(x='total',y='ins_premium',hue='no_previous',style='abbrev',data=dfcar)
plt.show()

# %%
sns.boxplot(x='total',y='ins_premium',data=dfcar)
plt.show()

# %%
sns.barplot(x='total',y='ins_premium',data=dfcar)
plt.show()
dfcar.total.value_counts()
# Out:
# 14.1    2
# 12.8    2
# 13.6    2
# 21.4    2
# 19.4    2
# 23.9    2
# 14.9    1
# 14.7    1
# 11.6    1
# 11.2    1
# 18.4    1
# 12.3    1
# 16.8    1
# 19.9    1
# 17.6    1
# 18.2    1
# 11.1    1
# 19.5    1
# 11.3    1
# 12.7    1
# 10.6    1
# 23.8    1
# 13.8    1
# 16.1    1
# 18.8    1
# 9.6     1
# 18.1    1
# 18.6    1
# 22.4    1
# 12.0    1
# 10.8    1
# 16.2    1
# 5.9     1
# 17.9    1
# 15.6    1
# 17.5    1
# 15.3    1
# 14.5    1
# 15.7    1
# 17.8    1
# 20.5    1
# 15.1    1
# 12.5    1
# 8.2     1
# 17.4    1
# Name: total, dtype: int64

# %%
sns.pairplot(dfcar)
plt.show()

# %%
sns.rugplot(dfcar.total)
plt.show()

# %%
sns.distplot(dfcar.ins_premium,hist=False)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dfcar.ins_premium)
plt.show()
# Out:
# D:\New folder\Python\envs\envr1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x='total',y='ins_premium',data=dfcar)
plt.show()

# %%
sns.relplot(x='total',y='ins_premium',hue='abbrev',col='speeding',col_wrap=2,data=dfcar)
plt.show()
